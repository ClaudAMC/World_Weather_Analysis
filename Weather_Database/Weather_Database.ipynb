# %%
# Import the dependencies

import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform( low = -90.000, high = 90.000, size = 2000)

lngs = np.random.uniform( low = -180.000, high = 180.000, size = 2000)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list

coordinates = list(lat_lngs)

# %%
from citipy import citipy 

# Create a list to hold the cities

cities = []

# Use for loop to identify nearest city for each lat and longatude combo

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then we add it to cities list.
    
    if city not in cities:
        
        cities.append(city)
        
# Print the city count to confirm total (1500) 

len(cities)
# Out:
# 735

# %%
# import requests module

import requests

#import API key

from config import weather_api_key

# %%
# Starting URL for Weather Map API Call

url = 'http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=' + weather_api_key

# %%
# Create an empty list to hold the weather data

city_data = []

# Print the beginning of the logging

print("Beginning Data Retrieval        ")
print('--------------------------------')


# Create counters.

record_count = 1

set_count = 1

# Loop through all the cities in our list



#loop through all the cities in our list

for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        
        record_count = 1
        
        time.sleep(60)
        
        
        
    # Create endpoint URL with each city.
    
    city_url = url + "&q=" + city.replace(" ","+")
    
    
    
    # Log the url, record, and set numbers and the city.
    
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    # Add 1 to the record count.
    
    record_count += 1
    
# Run an API request for each of the cities.
    
    try:
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        # Append the city info into city_data list.
        
        city_data.append({'City': city.title(),
                        'Lat': city_lat,
                        'Lng': city_lng,
                        'Max Temp': city_max_temp,
                        'Humidity': city_humidity,
                        'Cloudiness': city_clouds,
                        'Wind Speed': city_wind,
                        'Country': city_country,
                        'Current Description': city_description})
# If an error is experienced, skip the city.
    except:
        
        print('City not found. Skipping...')
        
        pass

# Indicate that Data loading is complete

print('----------------------------------')
print('Date Retrival Complete            ')
print('----------------------------------')
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of Set 1 | severo-kurilsk
# Processing Record 2 of Set 1 | lai
# Processing Record 3 of Set 1 | haimen
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | iqaluit
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | kaitangata
# Processing Record 9 of Set 1 | russell
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | southampton
# Processing Record 12 of Set 1 | dikson
# Processing Record 13 of Set 1 | kursumlija
# Processing Record 14 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 1 | goderich
# Processing Record 16 of Set 1 | sambava
# Processing Record 17 of Set 1 | kodiak
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 1 | mabaruma
# Processing Record 23 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 1 | ilulissat
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 1 | liuzhou
# Processing Record 28 of Set 1 | lebu
# Processing Record 29 of Set 1 | zhigansk
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | anadyr
# Processing Record 33 of Set 1 | port hedland
# Processing Record 34 of Set 1 | hvide sande
# Processing Record 35 of Set 1 | alta gracia
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | cockburn town
# Processing Record 42 of Set 1 | cuenca
# Processing Record 43 of Set 1 | glencoe
# Processing Record 44 of Set 1 | nikolskoye
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | saint-philippe
# Processing Record 47 of Set 1 | esperance
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | hasaki
# Processing Record 1 of Set 2 | stende
# Processing Record 2 of Set 2 | caravelas
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | barinas
# Processing Record 5 of Set 2 | boda
# Processing Record 6 of Set 2 | hilo
# Processing Record 7 of Set 2 | mozarlandia
# Processing Record 8 of Set 2 | bonavista
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | uige
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | kawambwa
# Processing Record 13 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 2 | priiskovyy
# Processing Record 15 of Set 2 | kampong cham
# Processing Record 16 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 2 | bandarbeyla
# Processing Record 19 of Set 2 | hualmay
# Processing Record 20 of Set 2 | bengkulu
# Processing Record 21 of Set 2 | ferrol
# Processing Record 22 of Set 2 | gorontalo
# Processing Record 23 of Set 2 | norman wells
# Processing Record 24 of Set 2 | barrow
# Processing Record 25 of Set 2 | tilichiki
# Processing Record 26 of Set 2 | los llanos de aridane
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | khatanga
# Processing Record 29 of Set 2 | weligama
# Processing Record 30 of Set 2 | illela
# Processing Record 31 of Set 2 | zavodouspenskoye
# Processing Record 32 of Set 2 | lima
# Processing Record 33 of Set 2 | geraldton
# Processing Record 34 of Set 2 | kande
# Processing Record 35 of Set 2 | antalaha
# Processing Record 36 of Set 2 | arraial do cabo
# Processing Record 37 of Set 2 | kamaishi
# Processing Record 38 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 2 | atuona
# Processing Record 41 of Set 2 | puerto ayora
# Processing Record 42 of Set 2 | victoria
# Processing Record 43 of Set 2 | simbahan
# Processing Record 44 of Set 2 | port hardy
# Processing Record 45 of Set 2 | pevek
# Processing Record 46 of Set 2 | havoysund
# Processing Record 47 of Set 2 | mahanoro
# Processing Record 48 of Set 2 | east london
# Processing Record 49 of Set 2 | alofi
# Processing Record 50 of Set 2 | kavaratti
# Processing Record 1 of Set 3 | tuatapere
# Processing Record 2 of Set 3 | longyearbyen
# Processing Record 3 of Set 3 | hopewell
# Processing Record 4 of Set 3 | santa maria
# Processing Record 5 of Set 3 | sinnamary
# Processing Record 6 of Set 3 | kalmunai
# Processing Record 7 of Set 3 | narasannapeta
# Processing Record 8 of Set 3 | vostok
# Processing Record 9 of Set 3 | touros
# Processing Record 10 of Set 3 | talnakh
# Processing Record 11 of Set 3 | katsuura
# Processing Record 12 of Set 3 | pisco
# Processing Record 13 of Set 3 | kaoma
# Processing Record 14 of Set 3 | fort nelson
# Processing Record 15 of Set 3 | reefton
# City not found. Skipping...
# Processing Record 16 of Set 3 | erzin
# Processing Record 17 of Set 3 | karakol
# Processing Record 18 of Set 3 | mikhaylovka
# Processing Record 19 of Set 3 | sao joao da barra
# Processing Record 20 of Set 3 | kruisfontein
# Processing Record 21 of Set 3 | saint george
# Processing Record 22 of Set 3 | mankono
# Processing Record 23 of Set 3 | te anau
# Processing Record 24 of Set 3 | seda
# Processing Record 25 of Set 3 | tagusao
# Processing Record 26 of Set 3 | pryshyb
# Processing Record 27 of Set 3 | sao filipe
# Processing Record 28 of Set 3 | guasdualito
# Processing Record 29 of Set 3 | lagoa
# Processing Record 30 of Set 3 | lozuvatka
# Processing Record 31 of Set 3 | lubango
# Processing Record 32 of Set 3 | alta floresta
# Processing Record 33 of Set 3 | zarate
# Processing Record 34 of Set 3 | igunga
# Processing Record 35 of Set 3 | liberal
# Processing Record 36 of Set 3 | grindavik
# Processing Record 37 of Set 3 | santa ines
# Processing Record 38 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 3 | klaksvik
# Processing Record 40 of Set 3 | nome
# Processing Record 41 of Set 3 | rakiv lis
# Processing Record 42 of Set 3 | cadereyta
# Processing Record 43 of Set 3 | ahipara
# Processing Record 44 of Set 3 | almaznyy
# Processing Record 45 of Set 3 | port alfred
# Processing Record 46 of Set 3 | la ronge
# Processing Record 47 of Set 3 | kahului
# Processing Record 48 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 3 | payyannur
# Processing Record 50 of Set 3 | miravci
# Processing Record 1 of Set 4 | loreto
# Processing Record 2 of Set 4 | samarai
# Processing Record 3 of Set 4 | moa
# Processing Record 4 of Set 4 | leningradskiy
# Processing Record 5 of Set 4 | lompoc
# Processing Record 6 of Set 4 | bethel
# Processing Record 7 of Set 4 | okahandja
# Processing Record 8 of Set 4 | lorengau
# Processing Record 9 of Set 4 | fairbanks
# Processing Record 10 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 4 | sedelnikovo
# City not found. Skipping...
# Processing Record 12 of Set 4 | cherskiy
# Processing Record 13 of Set 4 | turkan
# Processing Record 14 of Set 4 | barao de melgaco
# Processing Record 15 of Set 4 | san juan
# Processing Record 16 of Set 4 | kuytun
# Processing Record 17 of Set 4 | butaritari
# Processing Record 18 of Set 4 | ovalle
# Processing Record 19 of Set 4 | mahon
# Processing Record 20 of Set 4 | mar del plata
# Processing Record 21 of Set 4 | laguna
# Processing Record 22 of Set 4 | teknaf
# Processing Record 23 of Set 4 | saint-joseph
# Processing Record 24 of Set 4 | thompson
# Processing Record 25 of Set 4 | meulaboh
# Processing Record 26 of Set 4 | faanui
# Processing Record 27 of Set 4 | nanakuli
# Processing Record 28 of Set 4 | tayu
# Processing Record 29 of Set 4 | upernavik
# Processing Record 30 of Set 4 | vila velha
# Processing Record 31 of Set 4 | belmonte
# Processing Record 32 of Set 4 | castro
# Processing Record 33 of Set 4 | gizo
# Processing Record 34 of Set 4 | lisala
# Processing Record 35 of Set 4 | aklavik
# Processing Record 36 of Set 4 | codrington
# Processing Record 37 of Set 4 | port-gentil
# Processing Record 38 of Set 4 | coquimbo
# Processing Record 39 of Set 4 | kavieng
# Processing Record 40 of Set 4 | san julian
# Processing Record 41 of Set 4 | carnarvon
# Processing Record 42 of Set 4 | aksu
# Processing Record 43 of Set 4 | puerto ayacucho
# Processing Record 44 of Set 4 | narsaq
# Processing Record 45 of Set 4 | cabo san lucas
# Processing Record 46 of Set 4 | demidov
# Processing Record 47 of Set 4 | nishihara
# Processing Record 48 of Set 4 | oranjestad
# Processing Record 49 of Set 4 | honiara
# Processing Record 50 of Set 4 | puerto baquerizo moreno
# Processing Record 1 of Set 5 | sobolevo
# Processing Record 2 of Set 5 | saskylakh
# Processing Record 3 of Set 5 | saint-paul
# Processing Record 4 of Set 5 | batagay-alyta
# Processing Record 5 of Set 5 | eureka
# Processing Record 6 of Set 5 | mineral wells
# Processing Record 7 of Set 5 | isangel
# Processing Record 8 of Set 5 | tiksi
# Processing Record 9 of Set 5 | godda
# Processing Record 10 of Set 5 | sahuaripa
# Processing Record 11 of Set 5 | ribeira grande
# Processing Record 12 of Set 5 | calatayud
# Processing Record 13 of Set 5 | tiznit
# Processing Record 14 of Set 5 | yellowknife
# Processing Record 15 of Set 5 | fuling
# Processing Record 16 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 5 | praia
# Processing Record 18 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 5 | torbay
# Processing Record 20 of Set 5 | bambous virieux
# Processing Record 21 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 5 | magadan
# Processing Record 24 of Set 5 | port lincoln
# Processing Record 25 of Set 5 | panjab
# Processing Record 26 of Set 5 | bull savanna
# Processing Record 27 of Set 5 | ambon
# Processing Record 28 of Set 5 | ozernovskiy
# Processing Record 29 of Set 5 | carmo do rio claro
# Processing Record 30 of Set 5 | bonfim
# Processing Record 31 of Set 5 | adeje
# Processing Record 32 of Set 5 | teneguiban
# City not found. Skipping...
# Processing Record 33 of Set 5 | calabozo
# Processing Record 34 of Set 5 | bad lauterberg
# Processing Record 35 of Set 5 | kantang
# Processing Record 36 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 5 | bosaso
# Processing Record 38 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 5 | richards bay
# Processing Record 40 of Set 5 | lasa
# Processing Record 41 of Set 5 | polson
# Processing Record 42 of Set 5 | muros
# Processing Record 43 of Set 5 | palmares
# Processing Record 44 of Set 5 | kerrville
# Processing Record 45 of Set 5 | borba
# Processing Record 46 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 47 of Set 5 | hamadan
# Processing Record 48 of Set 5 | kudahuvadhoo
# Processing Record 49 of Set 5 | kapuskasing
# Processing Record 50 of Set 5 | sur
# Processing Record 1 of Set 6 | cidreira
# Processing Record 2 of Set 6 | dali
# Processing Record 3 of Set 6 | nyaunglebin
# Processing Record 4 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 5 of Set 6 | bathsheba
# Processing Record 6 of Set 6 | champerico
# Processing Record 7 of Set 6 | belaya gora
# Processing Record 8 of Set 6 | a coruna
# Processing Record 9 of Set 6 | santiago del estero
# Processing Record 10 of Set 6 | north bend
# Processing Record 11 of Set 6 | naze
# Processing Record 12 of Set 6 | saldanha
# Processing Record 13 of Set 6 | sulangan
# Processing Record 14 of Set 6 | airai
# Processing Record 15 of Set 6 | ust-shonosha
# Processing Record 16 of Set 6 | salalah
# Processing Record 17 of Set 6 | elizabeth city
# Processing Record 18 of Set 6 | ostrovnoy
# Processing Record 19 of Set 6 | provideniya
# Processing Record 20 of Set 6 | bredasdorp
# Processing Record 21 of Set 6 | meaford
# Processing Record 22 of Set 6 | sorland
# Processing Record 23 of Set 6 | kedougou
# Processing Record 24 of Set 6 | hambantota
# Processing Record 25 of Set 6 | buala
# Processing Record 26 of Set 6 | tuktoyaktuk
# Processing Record 27 of Set 6 | payo
# Processing Record 28 of Set 6 | canico
# Processing Record 29 of Set 6 | havre-saint-pierre
# Processing Record 30 of Set 6 | boyolangu
# Processing Record 31 of Set 6 | asayita
# City not found. Skipping...
# Processing Record 32 of Set 6 | vila franca do campo
# Processing Record 33 of Set 6 | nurlat
# Processing Record 34 of Set 6 | indramayu
# Processing Record 35 of Set 6 | madimba
# Processing Record 36 of Set 6 | mandalgovi
# Processing Record 37 of Set 6 | moose factory
# Processing Record 38 of Set 6 | lincoln
# Processing Record 39 of Set 6 | hami
# Processing Record 40 of Set 6 | padang
# Processing Record 41 of Set 6 | sao manuel
# Processing Record 42 of Set 6 | kralendijk
# Processing Record 43 of Set 6 | pokhara
# Processing Record 44 of Set 6 | stolin
# Processing Record 45 of Set 6 | ketchikan
# Processing Record 46 of Set 6 | shingu
# Processing Record 47 of Set 6 | borama
# City not found. Skipping...
# Processing Record 48 of Set 6 | jever
# Processing Record 49 of Set 6 | the pas
# Processing Record 50 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 1 of Set 7 | alyangula
# Processing Record 2 of Set 7 | ancud
# Processing Record 3 of Set 7 | zhitikara
# City not found. Skipping...
# Processing Record 4 of Set 7 | hofn
# Processing Record 5 of Set 7 | berdigestyakh
# Processing Record 6 of Set 7 | swidwin
# Processing Record 7 of Set 7 | frontera
# Processing Record 8 of Set 7 | abha
# Processing Record 9 of Set 7 | mana
# Processing Record 10 of Set 7 | el alto
# Processing Record 11 of Set 7 | roma
# Processing Record 12 of Set 7 | prado
# Processing Record 13 of Set 7 | pacific grove
# Processing Record 14 of Set 7 | biak
# Processing Record 15 of Set 7 | tadine
# Processing Record 16 of Set 7 | mount isa
# Processing Record 17 of Set 7 | pontian kecil
# Processing Record 18 of Set 7 | kloulklubed
# Processing Record 19 of Set 7 | misratah
# Processing Record 20 of Set 7 | olinda
# Processing Record 21 of Set 7 | biswan
# Processing Record 22 of Set 7 | tamboril
# Processing Record 23 of Set 7 | sioux lookout
# Processing Record 24 of Set 7 | luderitz
# Processing Record 25 of Set 7 | bairiki
# Processing Record 26 of Set 7 | mildura
# Processing Record 27 of Set 7 | ascension
# Processing Record 28 of Set 7 | bowen
# Processing Record 29 of Set 7 | caxito
# Processing Record 30 of Set 7 | arkhangelsk
# Processing Record 31 of Set 7 | karratha
# Processing Record 32 of Set 7 | bedi
# Processing Record 33 of Set 7 | mankachar
# Processing Record 34 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 7 | srednekolymsk
# Processing Record 36 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 7 | chuy
# Processing Record 38 of Set 7 | milingimbi
# City not found. Skipping...
# Processing Record 39 of Set 7 | whitehorse
# Processing Record 40 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 41 of Set 7 | andros
# Processing Record 42 of Set 7 | kindu
# Processing Record 43 of Set 7 | agua dulce
# Processing Record 44 of Set 7 | maceio
# Processing Record 45 of Set 7 | san vicente
# Processing Record 46 of Set 7 | coihaique
# Processing Record 47 of Set 7 | kapit
# Processing Record 48 of Set 7 | lokoja
# Processing Record 49 of Set 7 | ligayan
# Processing Record 50 of Set 7 | terrace
# Processing Record 1 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 2 of Set 8 | zhob
# Processing Record 3 of Set 8 | oarai
# Processing Record 4 of Set 8 | skibbereen
# Processing Record 5 of Set 8 | la macarena
# Processing Record 6 of Set 8 | aurangabad
# Processing Record 7 of Set 8 | fonte boa
# Processing Record 8 of Set 8 | shenjiamen
# Processing Record 9 of Set 8 | zhangye
# Processing Record 10 of Set 8 | lata
# Processing Record 11 of Set 8 | rawson
# Processing Record 12 of Set 8 | fortuna
# Processing Record 13 of Set 8 | pincher creek
# Processing Record 14 of Set 8 | lermontovka
# Processing Record 15 of Set 8 | mirabad
# Processing Record 16 of Set 8 | guerrero negro
# Processing Record 17 of Set 8 | consuelo
# Processing Record 18 of Set 8 | labuhan
# Processing Record 19 of Set 8 | poum
# Processing Record 20 of Set 8 | fare
# Processing Record 21 of Set 8 | san cristobal
# Processing Record 22 of Set 8 | amos
# Processing Record 23 of Set 8 | nizwa
# Processing Record 24 of Set 8 | jalingo
# Processing Record 25 of Set 8 | metz
# Processing Record 26 of Set 8 | marsh harbour
# Processing Record 27 of Set 8 | erechim
# Processing Record 28 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 8 | bakel
# Processing Record 30 of Set 8 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 31 of Set 8 | catuday
# Processing Record 32 of Set 8 | san quintin
# Processing Record 33 of Set 8 | lavrentiya
# Processing Record 34 of Set 8 | port macquarie
# Processing Record 35 of Set 8 | flinders
# Processing Record 36 of Set 8 | we
# City not found. Skipping...
# Processing Record 37 of Set 8 | mahebourg
# Processing Record 38 of Set 8 | kieta
# Processing Record 39 of Set 8 | mahajanga
# Processing Record 40 of Set 8 | gambiran
# Processing Record 41 of Set 8 | constitucion
# Processing Record 42 of Set 8 | suzhou
# Processing Record 43 of Set 8 | myitkyina
# Processing Record 44 of Set 8 | beloha
# Processing Record 45 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 46 of Set 8 | sumenep
# Processing Record 47 of Set 8 | walvis bay
# Processing Record 48 of Set 8 | marrakesh
# Processing Record 49 of Set 8 | kotelnich
# Processing Record 50 of Set 8 | staphorst
# Processing Record 1 of Set 9 | dingle
# Processing Record 2 of Set 9 | husavik
# Processing Record 3 of Set 9 | port-cartier
# Processing Record 4 of Set 9 | yumen
# Processing Record 5 of Set 9 | labytnangi
# Processing Record 6 of Set 9 | sivas
# Processing Record 7 of Set 9 | mehamn
# Processing Record 8 of Set 9 | gigmoto
# Processing Record 9 of Set 9 | tucumcari
# Processing Record 10 of Set 9 | gangapur
# Processing Record 11 of Set 9 | aswan
# Processing Record 12 of Set 9 | batemans bay
# Processing Record 13 of Set 9 | tocopilla
# Processing Record 14 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 9 | loudeac
# Processing Record 16 of Set 9 | banda aceh
# Processing Record 17 of Set 9 | valley city
# Processing Record 18 of Set 9 | port augusta
# Processing Record 19 of Set 9 | high level
# Processing Record 20 of Set 9 | bilma
# Processing Record 21 of Set 9 | mimongo
# Processing Record 22 of Set 9 | mgandu
# Processing Record 23 of Set 9 | chivay
# Processing Record 24 of Set 9 | kholodnyy
# Processing Record 25 of Set 9 | san patricio
# Processing Record 26 of Set 9 | zacualpan
# Processing Record 27 of Set 9 | umm lajj
# Processing Record 28 of Set 9 | tasiilaq
# Processing Record 29 of Set 9 | andenes
# Processing Record 30 of Set 9 | atambua
# Processing Record 31 of Set 9 | vagur
# Processing Record 32 of Set 9 | vallenar
# Processing Record 33 of Set 9 | dauphin
# Processing Record 34 of Set 9 | flin flon
# Processing Record 35 of Set 9 | peleduy
# Processing Record 36 of Set 9 | leh
# Processing Record 37 of Set 9 | jiaonan
# Processing Record 38 of Set 9 | rio gallegos
# Processing Record 39 of Set 9 | sao marcos
# Processing Record 40 of Set 9 | fukue
# Processing Record 41 of Set 9 | lubao
# Processing Record 42 of Set 9 | forestville
# Processing Record 43 of Set 9 | umtata
# Processing Record 44 of Set 9 | tual
# Processing Record 45 of Set 9 | ossora
# Processing Record 46 of Set 9 | uyuni
# Processing Record 47 of Set 9 | bitburg
# Processing Record 48 of Set 9 | tura
# Processing Record 49 of Set 9 | negombo
# Processing Record 50 of Set 9 | mbulu
# Processing Record 1 of Set 10 | majene
# Processing Record 2 of Set 10 | hobyo
# Processing Record 3 of Set 10 | orlik
# Processing Record 4 of Set 10 | marystown
# Processing Record 5 of Set 10 | gorkovskiy
# Processing Record 6 of Set 10 | babai
# Processing Record 7 of Set 10 | mariental
# Processing Record 8 of Set 10 | saint-francois
# Processing Record 9 of Set 10 | mangrol
# Processing Record 10 of Set 10 | abu samrah
# Processing Record 11 of Set 10 | ucluelet
# Processing Record 12 of Set 10 | alice springs
# Processing Record 13 of Set 10 | jumla
# Processing Record 14 of Set 10 | broome
# Processing Record 15 of Set 10 | tuy hoa
# Processing Record 16 of Set 10 | puerto leguizamo
# Processing Record 17 of Set 10 | wilmington
# Processing Record 18 of Set 10 | ifo
# Processing Record 19 of Set 10 | kombissiri
# Processing Record 20 of Set 10 | ust-maya
# Processing Record 21 of Set 10 | lucapa
# Processing Record 22 of Set 10 | plettenberg bay
# Processing Record 23 of Set 10 | oskarshamn
# Processing Record 24 of Set 10 | oistins
# Processing Record 25 of Set 10 | araguaina
# Processing Record 26 of Set 10 | quang ngai
# Processing Record 27 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 10 | independence
# Processing Record 29 of Set 10 | el sauzal
# Processing Record 30 of Set 10 | slave lake
# Processing Record 31 of Set 10 | bandar-e lengeh
# Processing Record 32 of Set 10 | taltal
# Processing Record 33 of Set 10 | sitka
# Processing Record 34 of Set 10 | omboue
# Processing Record 35 of Set 10 | vardo
# Processing Record 36 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 10 | bagdarin
# Processing Record 38 of Set 10 | broken hill
# Processing Record 39 of Set 10 | sibolga
# Processing Record 40 of Set 10 | hefei
# Processing Record 41 of Set 10 | mpraeso
# Processing Record 42 of Set 10 | cerrito
# Processing Record 43 of Set 10 | tabory
# Processing Record 44 of Set 10 | asosa
# Processing Record 45 of Set 10 | oussouye
# Processing Record 46 of Set 10 | troitsko-pechorsk
# Processing Record 47 of Set 10 | adolfo lopez mateos
# Processing Record 48 of Set 10 | gornopravdinsk
# Processing Record 49 of Set 10 | obo
# Processing Record 50 of Set 10 | davila
# Processing Record 1 of Set 11 | riyadh
# Processing Record 2 of Set 11 | shatrovo
# Processing Record 3 of Set 11 | impfondo
# Processing Record 4 of Set 11 | saran
# Processing Record 5 of Set 11 | the valley
# Processing Record 6 of Set 11 | agutaya
# Processing Record 7 of Set 11 | pedernales
# Processing Record 8 of Set 11 | san policarpo
# Processing Record 9 of Set 11 | hailar
# Processing Record 10 of Set 11 | port blair
# Processing Record 11 of Set 11 | acapulco
# Processing Record 12 of Set 11 | vaitape
# Processing Record 13 of Set 11 | altay
# Processing Record 14 of Set 11 | tateyama
# Processing Record 15 of Set 11 | hovd
# Processing Record 16 of Set 11 | faya
# Processing Record 17 of Set 11 | galle
# Processing Record 18 of Set 11 | freeport
# Processing Record 19 of Set 11 | meilu
# City not found. Skipping...
# Processing Record 20 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 21 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 11 | shanhetun
# Processing Record 23 of Set 11 | solsvik
# City not found. Skipping...
# Processing Record 24 of Set 11 | dimona
# Processing Record 25 of Set 11 | yulara
# Processing Record 26 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 27 of Set 11 | raga
# Processing Record 28 of Set 11 | beringovskiy
# Processing Record 29 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 11 | nuuk
# Processing Record 31 of Set 11 | dwarka
# Processing Record 32 of Set 11 | dunedin
# Processing Record 33 of Set 11 | sangueya
# Processing Record 34 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 11 | kaihua
# Processing Record 36 of Set 11 | verkh-usugli
# Processing Record 37 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 11 | lere
# Processing Record 39 of Set 11 | hokitika
# Processing Record 40 of Set 11 | saint-georges
# Processing Record 41 of Set 11 | vilyuysk
# Processing Record 42 of Set 11 | acarau
# Processing Record 43 of Set 11 | uruzgan
# Processing Record 44 of Set 11 | rudbar
# Processing Record 45 of Set 11 | agadez
# Processing Record 46 of Set 11 | maragogi
# Processing Record 47 of Set 11 | udachnyy
# Processing Record 48 of Set 11 | lixourion
# Processing Record 49 of Set 11 | odienne
# Processing Record 50 of Set 11 | boke
# Processing Record 1 of Set 12 | katobu
# Processing Record 2 of Set 12 | lengshuitan
# Processing Record 3 of Set 12 | metro
# Processing Record 4 of Set 12 | tommot
# Processing Record 5 of Set 12 | port keats
# Processing Record 6 of Set 12 | burnie
# Processing Record 7 of Set 12 | bawana
# Processing Record 8 of Set 12 | vestmannaeyjar
# Processing Record 9 of Set 12 | kropotkin
# Processing Record 10 of Set 12 | kamen-rybolov
# Processing Record 11 of Set 12 | pandamatenga
# Processing Record 12 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 13 of Set 12 | sheridan
# Processing Record 14 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 15 of Set 12 | xining
# Processing Record 16 of Set 12 | villarrica
# Processing Record 17 of Set 12 | norsup
# Processing Record 18 of Set 12 | nhulunbuy
# Processing Record 19 of Set 12 | axim
# Processing Record 20 of Set 12 | sakaraha
# Processing Record 21 of Set 12 | arman
# Processing Record 22 of Set 12 | kattivakkam
# Processing Record 23 of Set 12 | bulungu
# Processing Record 24 of Set 12 | korla
# Processing Record 25 of Set 12 | salinopolis
# Processing Record 26 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 27 of Set 12 | comodoro rivadavia
# Processing Record 28 of Set 12 | florianopolis
# Processing Record 29 of Set 12 | smithers
# Processing Record 30 of Set 12 | olafsvik
# Processing Record 31 of Set 12 | marawi
# Processing Record 32 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 12 | avera
# Processing Record 34 of Set 12 | yaring
# Processing Record 35 of Set 12 | krasnousolskiy
# City not found. Skipping...
# Processing Record 36 of Set 12 | gotsu
# Processing Record 37 of Set 12 | ternate
# Processing Record 38 of Set 12 | ust-nera
# Processing Record 39 of Set 12 | ramhormoz
# Processing Record 40 of Set 12 | capitan bado
# Processing Record 41 of Set 12 | vladimirskaya
# Processing Record 42 of Set 12 | cururupu
# Processing Record 43 of Set 12 | rameswaram
# Processing Record 44 of Set 12 | sfantu gheorghe
# Processing Record 45 of Set 12 | alta
# Processing Record 46 of Set 12 | palmer
# Processing Record 47 of Set 12 | zhezkazgan
# Processing Record 48 of Set 12 | charters towers
# Processing Record 49 of Set 12 | jurm
# Processing Record 50 of Set 12 | verkhnyaya inta
# Processing Record 1 of Set 13 | northam
# Processing Record 2 of Set 13 | cap malheureux
# Processing Record 3 of Set 13 | berlevag
# Processing Record 4 of Set 13 | kushmurun
# Processing Record 5 of Set 13 | kozhevnikovo
# Processing Record 6 of Set 13 | yamada
# Processing Record 7 of Set 13 | wanaka
# Processing Record 8 of Set 13 | glendive
# Processing Record 9 of Set 13 | chodavaram
# Processing Record 10 of Set 13 | mount gambier
# Processing Record 11 of Set 13 | tautira
# Processing Record 12 of Set 13 | los lunas
# Processing Record 13 of Set 13 | atherton
# Processing Record 14 of Set 13 | buchmany
# Processing Record 15 of Set 13 | casablanca
# Processing Record 16 of Set 13 | astara
# Processing Record 17 of Set 13 | havelock
# Processing Record 18 of Set 13 | nushki
# Processing Record 19 of Set 13 | huilong
# Processing Record 20 of Set 13 | general pico
# Processing Record 21 of Set 13 | matagami
# Processing Record 22 of Set 13 | clearlake
# Processing Record 23 of Set 13 | tabou
# Processing Record 24 of Set 13 | omsukchan
# Processing Record 25 of Set 13 | puebloviejo
# Processing Record 26 of Set 13 | santa fe
# Processing Record 27 of Set 13 | chara
# Processing Record 28 of Set 13 | saint anthony
# Processing Record 29 of Set 13 | kirakira
# Processing Record 30 of Set 13 | bonito
# Processing Record 31 of Set 13 | manjacaze
# Processing Record 32 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 33 of Set 13 | komsomolskiy
# Processing Record 34 of Set 13 | college
# Processing Record 35 of Set 13 | kamenka
# Processing Record 36 of Set 13 | souillac
# Processing Record 37 of Set 13 | nedjo
# Processing Record 38 of Set 13 | mattru
# Processing Record 39 of Set 13 | baruun-urt
# Processing Record 40 of Set 13 | tecoanapa
# Processing Record 41 of Set 13 | quijingue
# Processing Record 42 of Set 13 | quibor
# Processing Record 43 of Set 13 | guiratinga
# Processing Record 44 of Set 13 | boundiali
# Processing Record 45 of Set 13 | coffs harbour
# Processing Record 46 of Set 13 | lerwick
# Processing Record 47 of Set 13 | terra rica
# Processing Record 48 of Set 13 | nabire
# Processing Record 49 of Set 13 | eirunepe
# Processing Record 50 of Set 13 | puerto escondido
# Processing Record 1 of Set 14 | osmena
# Processing Record 2 of Set 14 | seoul
# Processing Record 3 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 4 of Set 14 | kodinsk
# Processing Record 5 of Set 14 | esmeraldas
# Processing Record 6 of Set 14 | sidi ali
# Processing Record 7 of Set 14 | black river
# Processing Record 8 of Set 14 | necochea
# Processing Record 9 of Set 14 | curitibanos
# Processing Record 10 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 11 of Set 14 | turmero
# Processing Record 12 of Set 14 | aykhal
# Processing Record 13 of Set 14 | manado
# Processing Record 14 of Set 14 | yar-sale
# Processing Record 15 of Set 14 | beihai
# Processing Record 16 of Set 14 | behbahan
# Processing Record 17 of Set 14 | guymon
# Processing Record 18 of Set 14 | sinjai
# Processing Record 19 of Set 14 | haines junction
# Processing Record 20 of Set 14 | sungaipenuh
# Processing Record 21 of Set 14 | kenitra
# Processing Record 22 of Set 14 | half moon bay
# Processing Record 23 of Set 14 | monaghan
# Processing Record 24 of Set 14 | manzhouli
# Processing Record 25 of Set 14 | guane
# Processing Record 26 of Set 14 | quatre cocos
# Processing Record 27 of Set 14 | strezhevoy
# Processing Record 28 of Set 14 | ola
# Processing Record 29 of Set 14 | nguruka
# Processing Record 30 of Set 14 | derzhavinsk
# Processing Record 31 of Set 14 | le pradet
# Processing Record 32 of Set 14 | shelburne
# Processing Record 33 of Set 14 | grand gaube
# Processing Record 34 of Set 14 | lushunkou
# City not found. Skipping...
# Processing Record 35 of Set 14 | lubu
# Processing Record 36 of Set 14 | kashi
# Processing Record 37 of Set 14 | bograd
# Processing Record 38 of Set 14 | santander
# Processing Record 39 of Set 14 | snasa
# Processing Record 40 of Set 14 | khilchipur
# Processing Record 41 of Set 14 | puerto madero
# Processing Record 42 of Set 14 | filingue
# Processing Record 43 of Set 14 | ugoofaaru
# Processing Record 44 of Set 14 | mecca
# Processing Record 45 of Set 14 | chardara
# Processing Record 46 of Set 14 | nanortalik
# Processing Record 47 of Set 14 | sereflikochisar
# Processing Record 48 of Set 14 | rovaniemi
# Processing Record 49 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 14 | adelaide
# Processing Record 1 of Set 15 | chernyshevskiy
# Processing Record 2 of Set 15 | anajatuba
# Processing Record 3 of Set 15 | lichinga
# Processing Record 4 of Set 15 | porto santo
# Processing Record 5 of Set 15 | joshimath
# Processing Record 6 of Set 15 | syamzha
# Processing Record 7 of Set 15 | akdepe
# Processing Record 8 of Set 15 | north platte
# Processing Record 9 of Set 15 | coroico
# Processing Record 10 of Set 15 | san lawrenz
# Processing Record 11 of Set 15 | kupang
# Processing Record 12 of Set 15 | santa rosa
# Processing Record 13 of Set 15 | chapais
# Processing Record 14 of Set 15 | palia kalan
# Processing Record 15 of Set 15 | yuancheng
# Processing Record 16 of Set 15 | zhanaozen
# Processing Record 17 of Set 15 | mariana
# Processing Record 18 of Set 15 | quchan
# Processing Record 19 of Set 15 | nantucket
# Processing Record 20 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 15 | sri aman
# Processing Record 22 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 15 | bodmin
# Processing Record 24 of Set 15 | honggang
# Processing Record 25 of Set 15 | hirara
# Processing Record 26 of Set 15 | ostersund
# Processing Record 27 of Set 15 | daska
# Processing Record 28 of Set 15 | severobaykalsk
# Processing Record 29 of Set 15 | draguignan
# Processing Record 30 of Set 15 | wattegama
# Processing Record 31 of Set 15 | inirida
# Processing Record 32 of Set 15 | nenjiang
# Processing Record 33 of Set 15 | oktyabrskoye
# Processing Record 34 of Set 15 | marathon
# Processing Record 35 of Set 15 | salisbury
# ----------------------------------
# Date Retrival Complete
# ----------------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame

city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Severo-Kurilsk  50.6789  156.1250     11.24        73          95
# 1             Lai   9.3952   16.2989     22.82        86         100
# 2          Haimen  23.1935  116.6142     27.94        80         100
# 3         Qaanaaq  77.4840  -69.3632     -0.12        77          38
# 4         Iqaluit  63.7506  -68.5145      0.85        80          75
# 5    Punta Arenas -53.1500  -70.9167      1.06        75          75
# 6       Busselton -33.6500  115.3333     19.19        78           5
# 7      Kaitangata -46.2817  169.8464      6.97        72          11
# 8         Russell  32.3502  -85.1999     29.78        94           0
# 9  Port Elizabeth -33.9180   25.5701      9.16        71           0
#
#    Wind Speed Country Current Description
# 0        1.14      RU     overcast clouds
# 1        2.54      TD     overcast clouds
# 2        5.59      CN          light rain
# 3        2.24      GL    scattered clouds
# 4        5.66      CA       broken clouds
# 5        7.20      CL       broken clouds
# 6       11.26      AU           clear sky
# 7        1.64      NZ          few clouds
# 8        0.00      US           clear sky
# 9        1.03      ZA           clear sky

# %%
new_coulumn_order = ['City','Country','Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness','Wind Speed', 'Current Description']

city_data_df = city_data_df[new_coulumn_order]

city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Severo-Kurilsk      RU  50.6789  156.1250     11.24        73          95
# 1             Lai      TD   9.3952   16.2989     22.82        86         100
# 2          Haimen      CN  23.1935  116.6142     27.94        80         100
# 3         Qaanaaq      GL  77.4840  -69.3632     -0.12        77          38
# 4         Iqaluit      CA  63.7506  -68.5145      0.85        80          75
# 5    Punta Arenas      CL -53.1500  -70.9167      1.06        75          75
# 6       Busselton      AU -33.6500  115.3333     19.19        78           5
# 7      Kaitangata      NZ -46.2817  169.8464      6.97        72          11
# 8         Russell      US  32.3502  -85.1999     29.78        94           0
# 9  Port Elizabeth      ZA -33.9180   25.5701      9.16        71           0
#
#    Wind Speed Current Description
# 0        1.14     overcast clouds
# 1        2.54     overcast clouds
# 2        5.59          light rain
# 3        2.24    scattered clouds
# 4        5.66       broken clouds
# 5        7.20       broken clouds
# 6       11.26           clear sky
# 7        1.64          few clouds
# 8        0.00           clear sky
# 9        1.03           clear sky

# %%
# Create the output file (CSV)

output_data_file = '../Weather_Database/WeatherPy_Database.csv'

# Export the City_Data into a CSV.

city_data_df.to_csv(output_data_file, index_label='City_ID')
